# %% [markdown]
# # Jupyter
# - Iptyhon system을 이용하여 동작한다.

# %% [markdown]
# ### Magic command
# - IPython에서 사용하는 명령어를 사용 가능
# - %를 앞에 붙이며, quickref, pwd, timeit

# %%
# %quickref

# %% [markdown]
# ### matplotlib 통합
# - IPython이 분석 컴퓨팅 환경에서 널리 사용되고 있는 이유는 데이터 시각화를 위한 matplotlib이나 다른 인터페이스 라이브러리와 잘 통합 되어 있기 때문이다

# %%
# %matplotlib
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50).cumsum())
