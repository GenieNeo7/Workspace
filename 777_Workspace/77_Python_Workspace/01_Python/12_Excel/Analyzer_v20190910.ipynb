# %%
import pandas as pd
import numpy as np

# %%
csvFile = pd.read_csv('test_csv_common.csv', delimiter = ',')

# %%
# workSheet = csvFile[csvFile.Separate == '신규']

# %%
sourcePath = csvFile.SourcePath

# %%
print('start')
tempSet = set({})
tempList = list([])
cartridges = list([])

for source in sourcePath:
    if("ktFixedTopology" in source):
        tempSource = source.split("\\")
        tempList.append(tempSource)

print('end')
tempList_df = pd.DataFrame(tempList)
tempList_df
# Out:
# start
# end
#             0                            1               2  \
# 0    Baseline  ktFixedProvisioningSolution  cartridgeBuild
# 1    Baseline              ktFixedTopology     xmlCatalogs
# 2    Baseline              ktFixedTopology     xmlCatalogs
# 3    Baseline              ktFixedTopology     xmlCatalogs
# 4    Baseline              ktFixedTopology       resources
# 5    Baseline              ktFixedTopology       resources
# 6    Baseline              ktFixedTopology       resources
# 7    Baseline              ktFixedTopology       resources
# 8    Baseline              ktFixedTopology       resources
# 9    Baseline              ktFixedTopology       resources
# 10   Baseline              ktFixedTopology       resources
# 11   Baseline              ktFixedTopology       resources
# 12   Baseline              ktFixedTopology       resources
# 13   Baseline              ktFixedTopology       resources
# 14   Baseline              ktFixedTopology       resources
# ...

# %%
tempSet
# Out:
# set()

# %%
tempList2 = set([])
for source2 in sourcePath:
    tempSource2 = source2.split("\\")
    if(len(tempSource2) > 2):
        tempList2.add(tempSource2[1])

tempList2
# Out:
# {'Customization',
#  'OracleComms_OSM_CommonDataDictionary',
#  'ktFixedAIAEBMDataDictionary',
#  'ktFixedCommon',
#  'ktFixedDesignAndAssignManagement',
#  'ktFixedFallout',
#  'ktFixedFieldWorkManagement',
#  'ktFixedFulfillmentConfirmation',
#  'ktFixedFulfillmentPatternMap',
#  'ktFixedMasterUpdate',
#  'ktFixedNotificationManagement',
#  'ktFixedOSMCustomization',
#  'ktFixedProductClassConfiguration',
#  'ktFixedProvisioningBase',
#  'ktFixedProvisioningCommonUtilities',
#  'ktFixedProvisioningResponseRecovery',
#  'ktFixedProvisioningResponseRecoveryEAR',
#  'ktFixedProvisioningResponseRecoveryMDB',
#  'ktFixedProvisioningSolution',
#  'ktFixedRecognitionRules',
#  'ktFixedResourceActivation',
#  'ktFixedServiceActivation',
#  'ktFixedTopology'}

# %%
# Out:
# ['osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
#  'osm-war',
# ...
